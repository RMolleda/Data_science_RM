# %% [markdown]
# - [Cows_and_Bulls]
#
# Say the number generated by the computer is 1038. An example interaction could look like this:
#
#   Welcome to the Cows and Bulls Game!
#
#   >Enter a number:
#
#   >> 1234
#
#   >>> 2 cows, 0 bulls
#
#   >> 1253
#
#   >>> 1 cow, 1 bull
#
#   ...
# Until the user guesses the number or write "STOP"

# %%
number = 1111

# %%
#Intento fallido vol.1

"""
def cows_and_bulls(input1):
    x = 0
    y = 0
    for pos, val in enumerate(str(input1)):
        for numpos, numval in enumerate(str(number)):
            if numpos == pos:
                if numval == val:
                    x += 1               
            elif val == numval:
                y += 1
            
    print(f"You have", x, "cows, and", y, "bulls.")

cows_and_bulls(input1 = input("Enter a number"))

"""
# Out:
# You have 4 cows, and 12 bulls.

# %%
#Intento fallido vol.2

"""
x = 0
y = 0
entry = "3451"
for pos, val in enumerate(str(entry)):
    for numpos, numval in enumerate(str(number)):
        if numpos == pos:
            if numval == val:
                x += 1               
        elif val == numval:
            y += 1
    
response = print(f"You have", x, "cows, and", y, "bulls.")
""""
# Out:
# You have 1 cows, and 3 bulls.

# %%
number = 1038

def cows_and_bulls(input1):
    x = 0
    y = 0
    for pos, val in enumerate(str(input1)):
        for numpos, numval in enumerate(str(number)):
            if val == numval and pos == numpos:
                x += 1
            elif val == numval:                    
                y += 1               
                
            
    print(f"You have", x, "cows, and", y, "bulls.")

cows_and_bulls(input1 = input("Enter a number"))
# Out:
# You have 1 cows, and 3 bulls.
