# %% [markdown]
# ### Se pide, usando regresión lineal:
#
# Dibujar con una línea la relación que hay entre la altura y la edad de los alumnos de la clase:
#
# - ¿Es una buena técnica para este tipo de problemas? ¿Por qué?
# - ¿Qué error se comete? Calcula los errores que está cometiendo tu modelo uno a uno (lo tienes que calcular tú con python). Aparte, usa el MSE y el RMSE. ¿Alguno es mejor para este problema?
# - Representa la matriz de correlación, ¿los datos están correlacionados?
# - ¿Qué ocurre si la altura se multiplica por dos? ¿Y si se multiplica solo la edad?

# %%
lista_edad_altura = [[29,  1.66], [22, 1.83], [31, 1.80], [27, 1.75], [22,1.82], [35,1.79], [34,1.90], [26,1.78], [26, 1.64], [23, 1.74], [24, 1.85], [28, 1.75], [23, 1.83], [32,1.74], [34, 1.57], [27, 1.58],[38,1.70],[22, 1.79]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.linear_model import LinearRegression
import seaborn as sns

# %%
"""
Clean and normalize data
"""
x = []
y = []
for i in lista_edad_altura:
    x.append(i[0])
    y.append(i[1])
X = np.array(x)
y = np.array(y)
X = X.reshape(-1, 1)
model = LinearRegression()

# %%
def initial_question():
    """
    Plot de la regresión lineal de los datos
    """
    model.fit(X, y)
    plt.scatter(X,Y)
    plt.plot(X, lr.predict(X), color="red")
initial_question()

# %%
y
# Out:
# array([1.66, 1.83, 1.8 , 1.75, 1.82, 1.79, 1.9 , 1.78, 1.64, 1.74, 1.85,
#        1.75, 1.83, 1.74, 1.57, 1.58, 1.7 , 1.79])

# %%
prediction = model.predict(X)

# %%
error = y - prediction
y.shape
error.shape
# Out:
# (18,)

# %%
sns.heatmap()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-26745035f384> in <module>
# ----> 1 sns.heatmap(X, y)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     556     if square:
#     557         ax.set_aspect("equal")
# --> 558     plotter.plot(ax, cbar_ax, kwargs)
#     559     return ax
#     560
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\matrix.py in plot(self, ax, cax, kws)
#     306
#     307         # Draw the heatmap
# --> 308         mesh = ax.pcolormesh(self.plot_data, cmap=self.cmap, **kws)
#     309
#     310         # Set the axis limits
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_axes.py in pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6106         collection.set_cmap(cmap)
#    6107         collection.set_norm(norm)
# -> 6108         collection._scale_norm(norm, vmin, vmax)
#    6109
#    6110         self.grid(False)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\cm.py in _scale_norm(self, norm, vmin, vmax)
#     251         """
#     252         if vmin is not None or vmax is not None:
# --> 253             self.set_clim(vmin, vmax)
#     254             if norm is not None:
#     255                 cbook.warn_deprecated(
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\cm.py in set_clim(self, vmin, vmax)
#     379                 pass
#     380         if vmin is not None:
# --> 381             self.norm.vmin = colors._sanitize_extrema(vmin)
#     382         if vmax is not None:
#     383             self.norm.vmax = colors._sanitize_extrema(vmax)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\colors.py in _sanitize_extrema(ex)
#     116         return ex
#     117     try:
# --> 118         ret = ex.item()
#     119     except AttributeError:
#     120         ret = float(ex)
#
# ValueError: can only convert an array of size 1 to a Python scalar

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-45-8b387b1c7c34> in <module>
# ----> 1 sns.heatmap(juanito)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     543     """
#     544     # Initialize the plotter object
# --> 545     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     546                           annot_kws, cbar, cbar_kws, xticklabels,
#     547                           yticklabels, mask)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     112         mask = _matrix_mask(data, mask)
#     113
# --> 114         plot_data = np.ma.masked_where(np.asarray(mask), plot_data)
#     115
#     116         # Get good names for the rows and columns
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\ma\core.py in masked_where(condition, a, copy)
#    1933     (cshape, ashape) = (cond.shape, a.shape)
#    1934     if cshape and cshape != ashape:
# -> 1935         raise IndexError("Inconsistent shape between the condition and the input"
#    1936                          " (got %s and %s)" % (cshape, ashape))
#    1937     if hasattr(a, '_mask'):
#
# IndexError: Inconsistent shape between the condition and the input (got (18, 1) and (18,))
