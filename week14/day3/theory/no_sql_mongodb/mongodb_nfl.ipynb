# %%
# !pip3 install pymongo
# !pip3 install pymongo[srv]
# !pip3 install dnspython
# Out:
# ...
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the 'z:\data_science\software\python\python_3.6.4\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the 'z:\data_science\software\python\python_3.6.4\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the 'z:\data_science\software\python\python_3.6.4\python.exe -m pip install --upgrade pip' command.

# %%
import pymongo
from pymongo import MongoClient
client = MongoClient('mongodb+srv://root:test@cluster0.vpkaj.mongodb.net/test')
client
# Out:
# MongoClient(host=['cluster0-shard-00-02.vpkaj.mongodb.net:27017', 'cluster0-shard-00-01.vpkaj.mongodb.net:27017', 'cluster0-shard-00-00.vpkaj.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-9gyqiq-shard-0', ssl=True)

# %%
#{Country:"Andorra "}

# %%
db = client['data']
db.list_collection_names()
# Out:
# ['data_collection', 'nfl']

# %%
collection = db['nfl']
collection.index_information()
# Out:
# {'_id_': {'v': 2, 'key': [('_id', 1)]}}

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('5f8ec191c8e009200c341d36'),
#  'Year': '2010',
#  'Date': '9/9/10',
#  'GameNumber': '1',
#  'GameLocation': 'Away',
#  'Team': 'Minnesota Vikings',
#  'TeamScore': '9',
#  'Opponent': 'New Orleans Saints',
#  'OppponentScore': '14',
#  'Result': 'Loss',
#  'PassingAttempts': '27',
#  'PassingCompletions': '15',
#  'PassingInterceptions': '1',
#  'PasserRating': '71.7',
#  'PassingSacks': '1',
#  'PassingSacksYardsLost': '9',
#  'PassingTouchdowns': '1',
#  'PassingYards': '171',
#  'ReceivingReceptions': '15',
#  'ReceivingTargets': '27',
#  'ReceivingTouchdowns': '1',
#  'ReceivingYards': '171',
#  'RushingAttempts': '23',
#  'RushingTouchdowns': '0',
#  'RushingYards': '91',
#  'DefenseTackes': '49',
#  'DefenseTackleAssists': '12',
#  'DefenseSacks': '1',
#  'DefenseSafeties': '0',
#  'DefenseInterceptions': '0',
#  'DefenseInterceptionYards': '0',
#  'DefenseInterceptionTouchdowns': '0',
#  'KickReturnAttempts': '2',
#  'KickReturnTouchdowns': '0',
# ...

# %%
import pandas as pd

df = pd.DataFrame(data=[collection.find_one()])
df
# Out:
#                         _id  Year    Date GameNumber GameLocation  \
# 0  5f8ec191c8e009200c341d36  2010  9/9/10          1         Away
#
#                 Team TeamScore            Opponent OppponentScore Result  ...  \
# 0  Minnesota Vikings         9  New Orleans Saints             14   Loss  ...
#
#   KickReturnTouchdowns KickReturnYards PuntReturnAttempts  \
# 0                    0              41                  2
#
#   PuntReturnTouchdowns PuntReturnYards FieldGoalAttempts FieldGoals  \
# 0                    0               2                 1          1
#
#   PuntingAttempts PuntsBlocked PuntingYards
# 0               7            0          310
#
# [1 rows x 43 columns]

# %%
fetch_date = collection.find({}, {'Date': '9/9/10'})
fetch_date

# %%
fetch_date = collection.find({}, {'Date': '9/9/10'})
for y in fetch_date:
    object_id = y["_id"]
    print(y)
# Out:
# {'_id': ObjectId('5f8ec191c8e009200c341d36'), 'Date': '9/9/10'}
# {'_id': ObjectId('5f8ec191c8e009200c341d37'), 'Date': '9/9/10'}
# {'_id': ObjectId('5f8ec191c8e009200c341d38'), 'Date': '9/9/10'}
# {'_id': ObjectId('5f8ec191c8e009200c341d39'), 'Date': '9/9/10'}
# {'_id': ObjectId('5f8ec191c8e009200c341d3a'), 'Date': '9/9/10'}
# {'_id': ObjectId('5f8ec191c8e009200c341d3b'), 'Date': '9/9/10'}
# {'_id': ObjectId('5f8ec191c8e009200c341d3c'), 'Date': '9/9/10'}
# {'_id': ObjectId('5f8ec191c8e009200c341d3d'), 'Date': '9/9/10'}
# {'_id': ObjectId('5f8ec191c8e009200c341d3e'), 'Date': '9/9/10'}
# {'_id': ObjectId('5f8ec191c8e009200c341d3f'), 'Date': '9/9/10'}
# {'_id': ObjectId('5f8ec191c8e009200c341d40'), 'Date': '9/9/10'}
# {'_id': ObjectId('5f8ec191c8e009200c341d41'), 'Date': '9/9/10'}
# {'_id': ObjectId('5f8ec191c8e009200c341d42'), 'Date': '9/9/10'}
# {'_id': ObjectId('5f8ec191c8e009200c341d43'), 'Date': '9/9/10'}
# {'_id': ObjectId('5f8ec191c8e009200c341d44'), 'Date': '9/9/10'}
# ...

# %%
for i in collection.find({},{'ReceivingTargets': '27',
 'ReceivingTouchdowns': '1',
 'ReceivingYards': '171',
 'RushingAttempts': '23',
 'RushingTouchdowns': '0',
 'RushingYards': '91',
 'DefenseTackes': '49',
 'DefenseTackleAssists': '12',
 'DefenseSacks': '1',}).limit(1):
    print(i)
# Out:
# {'_id': ObjectId('5f8ec191c8e009200c341d36'), 'ReceivingTargets': '27', 'ReceivingTouchdowns': '1', 'ReceivingYards': '171', 'RushingAttempts': '23', 'RushingTouchdowns': '0', 'RushingYards': '91', 'DefenseTackes': '49', 'DefenseTackleAssists': '12', 'DefenseSacks': '1'}

# %%
fetch_date = collection.find({}, {'ReceivingTargets': '27'})
for y in fetch_albania:
    object_id = y["_id"]
    print(object_id)
    for x in collection.find():
        if x["_id"] == object_id:
            print(x)
            break

# %%
fetch_albania = collection.find({},{'ReceivingTargets': '27'})
for x in fetch_albania:
    print(x)
    break
# Out:
# {'_id': ObjectId('5f8d4feac8e009200c340c62'), 'Country': 'Albania'}

# %%
fetch_date = collection.find({}, {'ReceivingTargets': '27'})
for x in fetch_albania:
    print(x)
# Out:
# {'_id': ObjectId('5f8d4feac8e009200c340c62'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8d4feac8e009200c340c5a'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8d4feac8e009200c340c57'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8d4feac8e009200c340c88'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8d4feac8e009200c340c66'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8d4feac8e009200c340c67'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8d4feac8e009200c340c74'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8d4feac8e009200c340c83'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8d4feac8e009200c340c90'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8d4feac8e009200c340c9a'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8d4feac8e009200c340caa'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8d4feac8e009200c340cee'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8d4feac8e009200c340cfc'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8d4feac8e009200c340cff'), 'Country': 'Albania'}
# ...

# %%
fetch_date = collection.find({}, {'_id': "5f8d4feac8e009200c340ca4"})
for x in fetch_albania:
    print(x)
# Out:
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# ...

# %%
# Inserting one record
record = {'_id': ObjectId('5f8ec191c8e009200c341d36'),
 'Year': '2010',
 'Date': '9/9/10',
 'GameNumber': '1',
 'GameLocation': 'Away',
 'Team': 'Minnesota Vikings',
 'TeamScore': '9',
 'Opponent': 'New Orleans Saints',
 'OppponentScore': '14',
 'Result': 'Loss',
 'PassingAttempts': '27',
 'PassingCompletions': '15',
 'PassingInterceptions': '1',
 'PasserRating': '71.7',
 'PassingSacks': '1',
 'PassingSacksYardsLost': '9',
 'PassingTouchdowns': '1',
 'PassingYards': '171',
 'ReceivingReceptions': '15',
 'ReceivingTargets': '27',
 'ReceivingTouchdowns': '1',
 'ReceivingYards': '171',
 'RushingAttempts': '23',
 'RushingTouchdowns': '0',
 'RushingYards': '91',
 'DefenseTackes': '49',
 'DefenseTackleAssists': '12',
 'DefenseSacks': '1',
 'DefenseSafeties': '0',
 'DefenseInterceptions': '0',
 'DefenseInterceptionYards': '0',
 'DefenseInterceptionTouchdowns': '0',
 'KickReturnAttempts': '2',
 'KickReturnTouchdowns': '0',
 'KickReturnYards': '41',
 'PuntReturnAttempts': '2',
 'PuntReturnTouchdowns': '0',
 'PuntReturnYards': '2',
 'FieldGoalAttempts': '1',
 'FieldGoals': '1',
 'PuntingAttempts': '7',
 'PuntsBlocked': '0',
 'PuntingYards': '310'
 }
collection.insert_one(record)

# %%
collection.insert_many(records)

# %%
# delete
collection.delete_one({'PasserRating': '71.7'})
